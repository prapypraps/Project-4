# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# importing important libraries

# %%
df=pd.read_csv('mobile_data.csv')    #READING THE DATA FILES

# %%
df
# Out:
#      Unnamed: 0                  Model          Colour  Memory  RAM  Battery_  \
# 0             0        Infinix SMART 7     Night Black      64    4      6000
# 1             1        Infinix SMART 7      Azure Blue      64    4      6000
# 2             2           MOTOROLA G32    Mineral Gray     128    8      5000
# 3             3               POCO C50      Royal Blue      32    2      5000
# 4             4        Infinix HOT 30i        Marigold     128    8      5000
# ..          ...                    ...             ...     ...  ...       ...
# 536         637  SAMSUNG Galaxy S23 5G           Cream     256    8      3900
# 537         638               LAVA Z21            Cyan      32    2      3100
# 538         639         Tecno Spark 8T  Turquoise Cyan      64    4      5000
# 539         641  SAMSUNG Galaxy A54 5G    Awesome Lime     128    8      5000
# 540         642               OPPO A77        Sky Blue     128    4      5000
#
# ...

# %%
# finding different attributes of the data to know insight

# %%
df.shape
# Out:
# (541, 12)

# %%
df.axes[0]
# Out:
# RangeIndex(start=0, stop=541, step=1)

# %%
df.axes[1]
# Out:
# Index(['Unnamed: 0', 'Model', 'Colour', 'Memory', 'RAM', 'Battery_',
#        'Rear Camera', 'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_',
#        'Prize'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Colour', 'Memory', 'RAM', 'Battery_',
#        'Rear Camera', 'Front Camera', 'AI Lens', 'Mobile Height', 'Processor_',
#        'Prize'],
#       dtype='object')

# %%
df.values
# Out:
# array([[0, 'Infinix SMART 7', 'Night Black', ..., 16.76,
#         'Unisoc Spreadtrum SC9863A1', '7,299'],
#        [1, 'Infinix SMART 7', 'Azure Blue', ..., 16.76,
#         'Unisoc Spreadtrum SC9863A1', '7,299'],
#        [2, 'MOTOROLA G32', 'Mineral Gray', ..., 16.64,
#         'Qualcomm Snapdragon 680', '11,999'],
#        ...,
#        [639, 'Tecno Spark 8T', 'Turquoise Cyan', ..., 16.76,
#         'MediaTek Helio G35', '9,990'],
#        [641, 'SAMSUNG Galaxy A54 5G', 'Awesome Lime', ..., 16.26,
#         'Exynos 1380, Octa Core ', '38,999'],
#        [642, 'OPPO A77', 'Sky Blue', ..., 16.66, 'Mediatek Helio G35',
#         '15,999']], dtype=object)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=541, step=1)

# %%
df.head(10)
# Out:
#    Unnamed: 0            Model         Colour  Memory  RAM  Battery_  \
# 0           0  Infinix SMART 7    Night Black      64    4      6000
# 1           1  Infinix SMART 7     Azure Blue      64    4      6000
# 2           2     MOTOROLA G32   Mineral Gray     128    8      5000
# 3           3         POCO C50     Royal Blue      32    2      5000
# 4           4  Infinix HOT 30i       Marigold     128    8      5000
# 5           5  Infinix HOT 30i   Glacier Blue     128    8      5000
# 6           6  Infinix HOT 30i   Mirror Black     128    8      5000
# 7           7  Infinix HOT 30i  Diamond White     128    8      5000
# 8           8  Infinix HOT 30i  Diamond White      64    4      5000
# 9           9  Infinix HOT 30i   Mirror Black      64    4      5000
#
#   Rear Camera Front Camera  AI Lens  Mobile Height  \
# 0        13MP          5MP        1          16.76
# 1        13MP          5MP        1          16.76
# ...

# %%
df.tail(10)
# Out:
#      Unnamed: 0                  Model           Colour  Memory  RAM  \
# 531         628          OPPO F21s Pro  Starlight Black     128    8
# 532         631        APPLE iPhone 12             Blue      64    8
# 533         632     SAMSUNG Galaxy A13            Peach     128    6
# 534         633         Nokia G11 Plus             Grey      64    4
# 535         636    SAMSUNG Galaxy A04e       Light Blue      64    3
# 536         637  SAMSUNG Galaxy S23 5G            Cream     256    8
# 537         638               LAVA Z21             Cyan      32    2
# 538         639         Tecno Spark 8T   Turquoise Cyan      64    4
# 539         641  SAMSUNG Galaxy A54 5G     Awesome Lime     128    8
# 540         642               OPPO A77         Sky Blue     128    4
#
#      Battery_ Rear Camera Front Camera  AI Lens  Mobile Height  \
# 531      4500        64MP         16MP        0          16.33
# 532      2815        12MP         12MP        0          15.49
# ...

# %%
df.info()   # getting more insight of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     541 non-null    int64
#  1   Model          541 non-null    object
#  2   Colour         541 non-null    object
#  3   Memory         541 non-null    int64
#  4   RAM            541 non-null    int64
#  5   Battery_       541 non-null    int64
#  6   Rear Camera    541 non-null    object
#  7   Front Camera   541 non-null    object
#  8   AI Lens        541 non-null    int64
#  9   Mobile Height  541 non-null    float64
#  10  Processor_     541 non-null    object
#  11  Prize          541 non-null    object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 50.8+ KB

# %%
df.isnull() # finding null values
# Out:
#      Unnamed: 0  Model  Colour  Memory    RAM  Battery_  Rear Camera  \
# 0         False  False   False   False  False     False        False
# 1         False  False   False   False  False     False        False
# 2         False  False   False   False  False     False        False
# 3         False  False   False   False  False     False        False
# 4         False  False   False   False  False     False        False
# ..          ...    ...     ...     ...    ...       ...          ...
# 536       False  False   False   False  False     False        False
# 537       False  False   False   False  False     False        False
# 538       False  False   False   False  False     False        False
# 539       False  False   False   False  False     False        False
# 540       False  False   False   False  False     False        False
#
#      Front Camera  AI Lens  Mobile Height  Processor_  Prize
# 0           False    False          False       False  False
# ...

# %%
df.isnull().sum()  # finding no od null values in each column 
                   # no null values so no treatment required
# Out:
# Unnamed: 0       0
# Model            0
# Colour           0
# Memory           0
# RAM              0
# Battery_         0
# Rear Camera      0
# Front Camera     0
# AI Lens          0
# Mobile Height    0
# Processor_       0
# Prize            0
# dtype: int64

# %%
df.duplicated().sum() # finding duplicates values
                      # no duplicate values so no treatment required
# Out:
# 0

# %%
df.describe()   #Getting further insights by knowing statistically imnportant data
# Out:
#        Unnamed: 0      Memory         RAM     Battery_     AI Lens  \
# count  541.000000  541.000000  541.000000   541.000000  541.000000
# mean   289.711645  110.550832    5.397412  4871.587800    0.062847
# std    182.359185   60.600694    1.984923   780.148862    0.242911
# min      0.000000   16.000000    2.000000   800.000000    0.000000
# 25%    135.000000   64.000000    4.000000  5000.000000    0.000000
# 50%    273.000000  128.000000    6.000000  5000.000000    0.000000
# 75%    434.000000  128.000000    8.000000  5000.000000    0.000000
# max    642.000000  256.000000    8.000000  7000.000000    1.000000
#
#        Mobile Height
# count     541.000000
# mean       16.431201
# std         2.523553
# min         4.500000
# 25%        16.510000
# 50%        16.710000
# 75%        16.940000
# max        41.940000

# %%
df1=df.describe().T #
df1
# Out:
#                count         mean         std    min      25%      50%  \
# Unnamed: 0     541.0   289.711645  182.359185    0.0   135.00   273.00
# Memory         541.0   110.550832   60.600694   16.0    64.00   128.00
# RAM            541.0     5.397412    1.984923    2.0     4.00     6.00
# Battery_       541.0  4871.587800  780.148862  800.0  5000.00  5000.00
# AI Lens        541.0     0.062847    0.242911    0.0     0.00     0.00
# Mobile Height  541.0    16.431201    2.523553    4.5    16.51    16.71
#
#                    75%      max
# Unnamed: 0      434.00   642.00
# Memory          128.00   256.00
# RAM               8.00     8.00
# Battery_       5000.00  7000.00
# AI Lens           0.00     1.00
# Mobile Height    16.94    41.94

# %%
df.describe(include="object") # getting info on data containing objects

# here we can see there are 6 columns which have object type data
# Out:
#            Model  Colour Rear Camera Front Camera               Processor_  \
# count        541     541         541          541                      541
# unique       187     275          14           13                      123
# top     vivo Y16  Yellow        50MP         16MP  Qualcomm Snapdragon 680
# freq           9      12         260          164                       33
#
#          Prize
# count      541
# unique     158
# top     15,999
# freq        23

# %%
# Treating the columns to convert them into int type so that we have more variables to create model more accurate


# Removing the 'MP' text and converting the columns to integer type

df['Rear Camera'] = df['Rear Camera'].str.replace('MP', '').astype(int)
df['Front Camera'] = df['Front Camera'].str.replace('MP', '').astype(int)

# Verifing the changes by displaying the first few rows again

df[['Model', 'Rear Camera', 'Front Camera']].head()
# Out:
#              Model  Rear Camera  Front Camera
# 0  Infinix SMART 7           13             5
# 1  Infinix SMART 7           13             5
# 2     MOTOROLA G32           50            16
# 3         POCO C50            8             5
# 4  Infinix HOT 30i           50             5

# %%
# Removing commas from the 'Prize' column and converting it to numeric values

df['Prize'] = df['Prize'].str.replace(',', '').astype(float)

# Verifing the changes by displaying the first few rows again

df[['Model', 'Prize']].head()
# Out:
#              Model    Prize
# 0  Infinix SMART 7   7299.0
# 1  Infinix SMART 7   7299.0
# 2     MOTOROLA G32  11999.0
# 3         POCO C50   5649.0
# 4  Infinix HOT 30i   8999.0

# %%
# dropping unnecessary columns

df3 = df.drop(columns=['Unnamed: 0','Model', 'Colour'])

# model is removed as it is object type and model cant be included as a feature 

# here we removed color as its unique values are more than 50 % of the total valies

# %%
# importing LabelEncoder to convert processor object type values to unique int type values


from sklearn.preprocessing import LabelEncoder   

le = LabelEncoder()

df3['Processor_'] = le.fit_transform(df3['Processor_'])

# %%
# checking data whether changes have been implemented or not

df3
# Out:
#      Memory  RAM  Battery_  Rear Camera  Front Camera  AI Lens  Mobile Height  \
# 0        64    4      6000           13             5        1          16.76
# 1        64    4      6000           13             5        1          16.76
# 2       128    8      5000           50            16        0          16.64
# 3        32    2      5000            8             5        0          16.56
# 4       128    8      5000           50             5        1          16.76
# ..      ...  ...       ...          ...           ...      ...            ...
# 536     256    8      3900           50            12        0          15.49
# 537      32    2      3100            5             2        0          12.70
# 538      64    4      5000           50             8        0          16.76
# 539     128    8      5000           50            32        0          16.26
# 540     128    4      5000           50             8        0          16.66
#
#      Processor_    Prize
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541 entries, 0 to 540
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Memory         541 non-null    int64
#  1   RAM            541 non-null    int64
#  2   Battery_       541 non-null    int64
#  3   Rear Camera    541 non-null    int32
#  4   Front Camera   541 non-null    int32
#  5   AI Lens        541 non-null    int64
#  6   Mobile Height  541 non-null    float64
#  7   Processor_     541 non-null    int32
#  8   Prize          541 non-null    float64
# dtypes: float64(2), int32(3), int64(4)
# memory usage: 31.8 KB

# %%
df3.describe()
# Out:
#            Memory         RAM     Battery_  Rear Camera  Front Camera  \
# count  541.000000  541.000000   541.000000   541.000000    541.000000
# mean   110.550832    5.397412  4871.587800    46.110906     11.992606
# std     60.600694    1.984923   780.148862    31.260416      9.053746
# min     16.000000    2.000000   800.000000     0.000000      0.000000
# 25%     64.000000    4.000000  5000.000000    13.000000      5.000000
# 50%    128.000000    6.000000  5000.000000    50.000000      8.000000
# 75%    128.000000    8.000000  5000.000000    50.000000     16.000000
# max    256.000000    8.000000  7000.000000   200.000000     60.000000
#
#           AI Lens  Mobile Height  Processor_         Prize
# count  541.000000     541.000000  541.000000    541.000000
# mean     0.062847      16.431201   61.528651  16228.375231
# std      0.242911       2.523553   32.456318  10793.588322
# min      0.000000       4.500000    0.000000    920.000000
# ...

# %%
# Histogram to understaqnd distribution

for i in df3.select_dtypes(include='number').columns:
    sns.histplot(data=df3,x=i, bins=15,color='orange', edgecolor='black')
    plt.show()

# %%
df3.columns
# Out:
# Index(['Memory', 'RAM', 'Battery_', 'Rear Camera', 'Front Camera', 'AI Lens',
#        'Mobile Height', 'Processor_', 'Prize'],
#       dtype='object')

# %%
# using scatter plot to know the distribution more clearly
for i in ['Memory', 'RAM', 'Battery_', 'Rear Camera', 'Front Camera', 'AI Lens',
       'Mobile Height', 'Processor_', 'Prize' ]:
    sns.scatterplot(data=df3,color='green',x=i,y='Prize')
    plt.show()

# %%
# creating a boxplot for all features to know about distributions and outliers


for i in df3.select_dtypes(include='number').columns:
    sns.boxplot(data=df3,color='violet',x=i)
    plt.show()

# %%
for i in ['Memory', 'RAM', 'Battery_', 'Rear Camera', 'Front Camera', 'AI Lens',
       'Mobile Height', 'Processor_', 'Prize']:
    sns.violinplot(data=df3, color='maroon',x=i, )
    
    plt.show()

# %%
# Treating the ouliers by defining a function whisper

def wisker (col):
    q1,q3=np.percentile(col,[25,75])
    iqr=q3-q1
    lw=q1-1.5*iqr
    uw=q3+1.5*iqr
    return lw,uw

# %%
# Treating the ouliers for better model accuracy 
# note- here we didnt use processor columns as it had no outliers
for i in ['Memory', 'RAM', 'Battery_', 'Rear Camera', 'Front Camera', 'AI Lens',
       'Mobile Height',  'Prize']:
    lw,uw=wisker(df3[i])
    df3[i]=np.where(df3[i]<lw,lw,df[i])
    df3[i]=np.where(df3[i]>uw,uw,df[i])

# %%
# Checking whether outliers have been treated or now

for i in ['Memory', 'RAM', 'Battery_', 'Rear Camera', 'Front Camera', 'AI Lens',
       'Mobile Height', 'Processor_', 'Prize']: # checking wether it is resolved or now
    sns.boxplot(df3[i],color='darkblue')
    plt.show()

# %%
# violinplot 

for i in ['Memory', 'RAM', 'Battery_', 'Rear Camera', 'Front Camera', 'AI Lens',
       'Mobile Height', 'Processor_', 'Prize']:
    sns.violinplot(data=df3,x=i, )
    
    plt.show()

# %%
# correlation with heat map to interpret relationship

s=df3.select_dtypes(include='number').corr()

# %%
#correlation data

s
# Out:
#                  Memory       RAM  Battery_  Rear Camera  Front Camera  \
# Memory         1.000000  0.665364 -0.007482     0.537111      0.559682
# RAM            0.665364  1.000000 -0.056341     0.527541      0.571952
# Battery_      -0.007482 -0.056341  1.000000     0.292034      0.135799
# Rear Camera    0.537111  0.527541  0.292034     1.000000      0.566661
# Front Camera   0.559682  0.571952  0.135799     0.566661      1.000000
# AI Lens             NaN       NaN       NaN          NaN           NaN
# Mobile Height  0.082474  0.058398  0.935658     0.345679      0.290128
# Processor_    -0.156441 -0.108733 -0.091230    -0.112499     -0.047764
# Prize          0.692721  0.651490  0.103929     0.541582      0.723877
#
#                AI Lens  Mobile Height  Processor_     Prize
# Memory             NaN       0.082474   -0.156441  0.692721
# RAM                NaN       0.058398   -0.108733  0.651490
# Battery_           NaN       0.935658   -0.091230  0.103929
# ...

# %%
# plotting heatmap

plt.figure(figsize=(15,15))
sns.heatmap(s,annot=True)
# Out:
# <Axes: >

# %%
sq=df3.select_dtypes(include='number').skew()

# %%
# knowing skewness of the data

sq
# Out:
# Memory           0.611723
# RAM              0.067617
# Battery_        -4.522299
# Rear Camera      0.317277
# Front Camera     1.254016
# AI Lens          0.000000
# Mobile Height   -5.313922
# Processor_       0.024830
# Prize            0.803887
# dtype: float64

# %%
# plotting hist graph for better understanding

df3.hist(bins=15, edgecolor='black',color='Yellow', grid=False)
plt.tight_layout()
plt.show()

# %%
df3
# Out:
#      Memory  RAM  Battery_  Rear Camera  Front Camera  AI Lens  Mobile Height  \
# 0      64.0  4.0    5000.0         13.0           5.0      0.0          16.76
# 1      64.0  4.0    5000.0         13.0           5.0      0.0          16.76
# 2     128.0  8.0    5000.0         50.0          16.0      0.0          16.64
# 3      32.0  2.0    5000.0          8.0           5.0      0.0          16.56
# 4     128.0  8.0    5000.0         50.0           5.0      0.0          16.76
# ..      ...  ...       ...          ...           ...      ...            ...
# 536   224.0  8.0    3900.0         50.0          12.0      0.0          15.49
# 537    32.0  2.0    3100.0          5.0           2.0      0.0          12.70
# 538    64.0  4.0    5000.0         50.0           8.0      0.0          16.76
# 539   128.0  8.0    5000.0         50.0          32.0      0.0          16.26
# 540   128.0  4.0    5000.0         50.0           8.0      0.0          16.66
#
#      Processor_    Prize
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
df4 = pd.DataFrame(df3)

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Fit and transform the data
scaled_data = scaler.fit_transform(df4)

# Convert the scaled data back to a DataFrame for easy handling
scaled_df = pd.DataFrame(scaled_data, columns=df4.columns)

# Show the scaled data
print(scaled_df)
# Out:
#        Memory       RAM  Battery_  Rear Camera  Front Camera  AI Lens  \
# 0   -0.816382 -0.704665  0.300825    -1.231089     -0.902624      0.0
# 1   -0.816382 -0.704665  0.300825    -1.231089     -0.902624      0.0
# 2    0.390346  1.312392  0.300825     0.211735      0.620130      0.0
# 3   -1.419746 -1.713193  0.300825    -1.426065     -0.902624      0.0
# 4    0.390346  1.312392  0.300825     0.211735     -0.902624      0.0
# ..        ...       ...       ...          ...           ...      ...
# 536  2.200438  1.312392 -1.264165     0.211735      0.066401      0.0
# 537 -1.419746 -1.713193 -2.402339    -1.543051     -1.317921      0.0
# 538 -0.816382 -0.704665  0.300825     0.211735     -0.487328      0.0
# 539  0.390346  1.312392  0.300825     0.211735      2.835046      0.0
# 540  0.390346 -0.704665  0.300825     0.211735     -0.487328      0.0
#
#      Mobile Height  Processor_     Prize
# 0         0.210866    1.587333 -0.996799
# 1         0.210866    1.587333 -0.996799
# ...

# %%
scaled_df=scaled_df.drop(244) # this particular row was deleted as it had a complex error which was not getting treated

# %%
scaled_df
# Out:
#        Memory       RAM  Battery_  Rear Camera  Front Camera  AI Lens  \
# 0   -0.816382 -0.704665  0.300825    -1.231089     -0.902624      0.0
# 1   -0.816382 -0.704665  0.300825    -1.231089     -0.902624      0.0
# 2    0.390346  1.312392  0.300825     0.211735      0.620130      0.0
# 3   -1.419746 -1.713193  0.300825    -1.426065     -0.902624      0.0
# 4    0.390346  1.312392  0.300825     0.211735     -0.902624      0.0
# ..        ...       ...       ...          ...           ...      ...
# 536  2.200438  1.312392 -1.264165     0.211735      0.066401      0.0
# 537 -1.419746 -1.713193 -2.402339    -1.543051     -1.317921      0.0
# 538 -0.816382 -0.704665  0.300825     0.211735     -0.487328      0.0
# 539  0.390346  1.312392  0.300825     0.211735      2.835046      0.0
# 540  0.390346 -0.704665  0.300825     0.211735     -0.487328      0.0
#
#      Mobile Height  Processor_     Prize
# 0         0.210866    1.587333 -0.996799
# 1         0.210866    1.587333 -0.996799
# ...

# %%
scaled_df.columns
# Out:
# Index(['Memory', 'RAM', 'Battery_', 'Rear Camera', 'Front Camera', 'AI Lens',
#        'Mobile Height', 'Processor_', 'Prize'],
#       dtype='object')

# %%
# defining independent and dependent variables for prediction


X = scaled_df[['Memory', 'RAM', 'Battery_', 'Rear Camera', 'Front Camera', 'AI Lens',
       'Mobile Height', 'Processor_']]  # Independent variables
y = scaled_df['Prize']  # Dependent/target variable

# %%
# importing train_test_split

from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=42)

# %%
#importing linear regression 

from sklearn.linear_model import LinearRegression

# Initialize the linear regression model
model = LinearRegression()

# %%
# Training the model using the training data

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions on the test data

y_pred = model.predict(X_test)


y_pred
# Out:
# array([-0.38521259, -1.17603184,  0.78143483, -0.42200634, -0.21348402,
#        -0.00264844, -0.75456195,  1.64106887,  0.34450884, -0.85898644,
#         0.12537149,  2.1413244 ,  0.63799177,  0.85443264, -0.27499485,
#         0.01517153,  0.30162328,  0.5588711 ,  0.78865614,  0.52728097,
#        -0.9374863 ,  0.55702077,  0.39429424,  0.33023434, -0.76474706,
#         0.51607059, -1.0561853 ,  0.7408394 , -0.57222429,  1.95427871,
#        -0.9374863 ,  0.04604384, -2.23097674,  1.51066408,  0.63799177,
#         0.5564638 , -0.54688745,  0.2746618 ,  0.01517153, -0.3466985 ,
#        -0.21321458,  1.92466947,  0.57706077,  1.0253249 , -1.10442613,
#         0.3690591 , -0.78242917, -0.20210532, -0.62237422, -1.06173539,
#         0.1872297 ,  1.99310035, -0.58567099, -0.66569395, -0.79801831,
#         0.91022462,  0.7274807 ,  1.49228087, -0.35018085, -0.00290535,
#        -1.84523462,  1.13881752, -1.06173539,  1.35452997, -1.1935573 ,
# ...

# %%
pd.DataFrame({'Y_Test':y_test,'Y_Pred':y_pred})
# Out:
#        Y_Test    Y_Pred
# 229 -0.850940 -0.385213
# 73  -1.118348 -1.176032
# 522  2.280892  0.781435
# 86  -0.547068 -0.422006
# 470 -0.352589 -0.213484
# ..        ...       ...
# 499  0.182227  1.210298
# 148 -0.668617 -0.454157
# 46  -0.911715 -0.636758
# 93  -0.668617 -0.565378
# 407 -0.790166 -0.384686
#
# [108 rows x 2 columns]

# %%
# checking the coefficient

pd.DataFrame(model.coef_,X.columns,columns=['Coefficients'])
# Out:
#                Coefficients
# Memory             0.276682
# RAM                0.226660
# Battery_          -0.579455
# Rear Camera        0.026537
# Front Camera       0.284537
# AI Lens            0.000000
# Mobile Height      0.711344
# Processor_         0.000203

# %%
# Checking the accuracy of the model and knowing other score of the data

# %%
model.score(X_test,y_test)
# Out:
# 0.7716554452189853

# %%
model.score(X_test,y_test).round(5)
# Out:
# 0.77166

# %%
model.score(X_train,y_train).round(5)
# Out:
# 0.69921

# %%
from sklearn import metrics

# %%
MAE = metrics.mean_absolute_error(y_test,y_pred)
MSE = metrics.mean_squared_error(y_test,y_pred)
RMSE = np.sqrt(MSE)

# %%
pd.DataFrame([MAE,MSE,RMSE],index=['MAE','MSE','RMSE'],columns=['Metrics'])
# Out:
#        Metrics
# MAE   0.340090
# MSE   0.248863
# RMSE  0.498862

# %%
# Plotting all features against Prize with regression lines
features = X_test.columns
plt.figure(figsize=(15, 20))

for i, feature in enumerate(features, 1):
    plt.subplot(3, 3, i)
    sns.regplot(x=X_test[feature], y=y_test, line_kws={"color": "red"}, scatter_kws={"alpha": 0.6})
    plt.xlabel(feature)
    plt.ylabel('Prize')
    plt.title(f'{feature} vs Prize')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Scatter plot of actual vs predicted values
plt.scatter(y_test, y_pred, color='blue', label="Actuall values")

# Ploting a line that represents the ideal case (perfect prediction)
plt.plot(y_test, y_test, color='red', linewidth=2, label="Regression Line")

# Adding labels and title
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Linear Regression')

# Displaying the plot with legend
plt.legend()
plt.show()

# %%
# Thank you
